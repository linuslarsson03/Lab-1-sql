# %% [markdown]
# ## Pandas repetition

# %%
import pandas as pd

df = pd.read_excel("data/calories.xlsx")
df.head()
# Out:
#   FoodCategory             FoodItem per100grams Cals_per100grams  \
# 0  CannedFruit           Applesauce        100g           62 cal
# 1  CannedFruit      Canned Apricots        100g           48 cal
# 2  CannedFruit  Canned Blackberries        100g           92 cal
# 3  CannedFruit   Canned Blueberries        100g           88 cal
# 4  CannedFruit      Canned Cherries        100g           54 cal
#
#   KJ_per100grams
# 0         260 kJ
# 1         202 kJ
# 2         386 kJ
# 3         370 kJ
# 4         227 kJ

# %%
df.tail()
# Out:
#      FoodCategory          FoodItem per100grams Cals_per100grams  \
# 2220      Spreads  Sunflower Butter        100g          617 cal
# 2221      Spreads          Tapenade        100g          233 cal
# 2222      Spreads   Unsalted Butter        100g          717 cal
# 2223      Spreads          Vegemite        100g          180 cal
# 2224      Spreads        Wild Honey        100g          286 cal
#
#      KJ_per100grams
# 2220        2591 kJ
# 2221         979 kJ
# 2222        3011 kJ
# 2223         756 kJ
# 2224        1201 kJ

# %%
df.sample()
# Out:
#       FoodCategory      FoodItem per100grams Cals_per100grams KJ_per100grams
# 2052  Herbs&Spices  White Pepper        100g          296 cal        1243 kJ

# %% [markdown]
# ## Eda

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FoodCategory      2225 non-null   object
#  1   FoodItem          2225 non-null   object
#  2   per100grams       2225 non-null   object
#  3   Cals_per100grams  2225 non-null   object
#  4   KJ_per100grams    2225 non-null   object
# dtypes: object(5)
# memory usage: 87.0+ KB

# %%
df["Cals_per100grams"].value_counts().head(5)
# Out:
# Cals_per100grams
# 250 cal    26
# 100 cal    26
# 0 cal      23
# 42 cal     20
# 884 cal    19
# Name: count, dtype: int64

# %%
food_categories = df["FoodCategory"].value_counts().head(5)
food_categories
# Out:
# FoodCategory
# BakingIngredients    95
# Cakes&Pies           91
# Herbs&Spices         90
# Beer                 85
# Candy&Sweets         81
# Name: count, dtype: int64

# %%
food_categories.plot

# %%
type(food_categories)
# Out:
# pandas.core.series.Series

# %%
print(f"{type(food_categories) = }")
print(f"{type(df) = }")
print(f"{type(df['FoodItem']) = }")
# Out:
# type(food_categories) = <class 'pandas.core.series.Series'>
# type(df) = <class 'pandas.core.frame.DataFrame'>
# type(df['FoodItem']) = <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Clean columns
# per100grams -> int, name:per100
#
# Cals_per100grams -> int, name:calories

# %%
df["per100grams"] = df["per100grams"].str[:3].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FoodCategory      2225 non-null   object
#  1   FoodItem          2225 non-null   object
#  2   per100grams       2225 non-null   int64
#  3   Cals_per100grams  2225 non-null   object
#  4   KJ_per100grams    2225 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 87.0+ KB

# %%
df["per100grams"]
# Out:
# 0       100
# 1       100
# 2       100
# 3       100
# 4       100
#        ...
# 2220    100
# 2221    100
# 2222    100
# 2223    100
# 2224    100
# Name: per100grams, Length: 2225, dtype: int64

# %%
df["Cals_per100grams"] = df["Cals_per100grams"].str[:-3].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FoodCategory      2225 non-null   object
#  1   FoodItem          2225 non-null   object
#  2   per100grams       2225 non-null   int64
#  3   Cals_per100grams  2225 non-null   int64
#  4   KJ_per100grams    2225 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 87.0+ KB

# %%
df["Cals_per100grams"]
# Out:
# 0        62
# 1        48
# 2        92
# 3        88
# 4        54
#        ...
# 2220    617
# 2221    233
# 2222    717
# 2223    180
# 2224    286
# Name: Cals_per100grams, Length: 2225, dtype: int64

# %%
df_cleaned = df.rename({"Cals_per100grams": "calories", "per100grams": "per100"}, axis="columns")
df_cleaned.head()
# Out:
#   FoodCategory             FoodItem  per100  calories KJ_per100grams
# 0  CannedFruit           Applesauce     100        62         260 kJ
# 1  CannedFruit      Canned Apricots     100        48         202 kJ
# 2  CannedFruit  Canned Blackberries     100        92         386 kJ
# 3  CannedFruit   Canned Blueberries     100        88         370 kJ
# 4  CannedFruit      Canned Cherries     100        54         227 kJ
